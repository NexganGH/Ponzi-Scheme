# %%
from networks import *
from simulation import *

# %%
erNetwork = ErNetwork(k_avg=6, n_nodes=10000)
erNetwork.build()
erNetwork.save_json('my_networks/er1.json')

erNetwork.print_k_info()
# Out:
# Building ER network...
# Network salvato in my_networks/er1.json
# 'Mean: 6.054, k^2: 42.682'

# %%
## TO GENERATE
baNetwork = BaNetwork.from_average_k(6, 10000)
baNetwork.build()
baNetwork.save_json('my_networks/ba1.json')

baNetwork.print_k_info()
# Out:
# Building network...
# 5.00% complete
# 10.00% complete
# 15.01% complete
# 20.01% complete
# 25.01% complete
# 30.01% complete
# 35.01% complete
# 40.01% complete
# 45.01% complete
# 50.01% complete
# 55.01% complete
# 60.02% complete
# 65.02% complete
# 70.02% complete
# 75.03% complete
# 80.03% complete
# 85.04% complete
# 90.05% complete
# 95.05% complete
# Network salvato in my_networks/ba1.json
# 'Mean: 5.9988, k^2: 113.5392'

# %%
wsNetwork = WattsStrogatzNetwork(n_nodes=10000, k=6, p=0.4)
wsNetwork.build()
wsNetwork.save_json('my_networks/ws1.json')
wsNetwork.print_k_info()
# Out:
# Building Watts-Strogatz Small-World Network...
# First step, 5.00% complete
# First step, 10.00% complete
# First step, 15.01% complete
# First step, 20.01% complete
# First step, 25.01% complete
# First step, 30.01% complete
# First step, 35.01% complete
# First step, 40.01% complete
# First step, 45.01% complete
# First step, 50.01% complete
# First step, 55.01% complete
# First step, 60.02% complete
# First step, 65.02% complete
# First step, 70.02% complete
# First step, 75.03% complete
# First step, 80.03% complete
# First step, 85.04% complete
# First step, 90.05% complete
# First step, 95.05% complete
# Second step, 5.00% complete
# Second step, 10.00% complete
# Second step, 15.01% complete
# Second step, 20.01% complete
# Second step, 25.01% complete
# Second step, 30.01% complete
# Second step, 35.01% complete
# Second step, 40.01% complete
# Second step, 45.01% complete
# Second step, 50.01% complete
# Second step, 55.01% complete
# Second step, 60.02% complete
# Second step, 65.02% complete
# Second step, 70.02% complete
# Second step, 75.03% complete
# Second step, 80.03% complete
# Second step, 85.04% complete
# Second step, 90.05% complete
# Second step, 95.05% complete
# Network salvato in my_networks/ws1.json
# 'Mean: 6.0, k^2: 37.944'

# %%
## To generate

# %%
plotter = PonziPlotter()

par_list = []
for x in [0.05, 0.075, 0.1, 0.125, 0.150, 0.175, 0.2]:
    erNet = ErNetwork.load_json('my_networks/er1.json')
    par = PonziParameters(M=1, starting_capital=50, lambda_ = lambda t: x, mu=lambda t:0.05, rp= lambda t: 0.1, rr=lambda t: 0.05)
    sim = PonziSimulation(erNet, par, max_time_units=30*12)
    res = sim.simulate_ponzi()
    plotter.add_simulation(res, r'$\lambda=' + str(x) + '$', show_potential=False)
plotter.plot('changing_lambda_er')
# Out:
# Network caricato da my_networks/er1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/er1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/er1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/er1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/er1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/er1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/er1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete

# %%
plotter = PonziPlotter()

for x in [0.05, 0.075, 0.1, 0.125, 0.150, 0.175, 0.2]:
    baNet = BaNetwork.load_json('my_networks/ba1.json')
    par = PonziParameters(M=1, starting_capital=50, lambda_ = lambda t: x, mu=lambda t:0.05, rp= lambda t: 0.1, rr=lambda t: 0.05)
    sim = PonziSimulation(baNet, par, max_time_units=30*12)
    res = sim.simulate_ponzi()
    plotter.add_simulation(res, r'$\lambda=' + str(x) + '$', show_potential=False)
plotter.plot('changing_lambda_ba')
# Out:
# Network caricato da my_networks/ba1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ba1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ba1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ba1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ba1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ba1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ba1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete

# %%
plotter = PonziPlotter()

for x in [0.05, 0.075, 0.1, 0.125, 0.150, 0.175, 0.2]:
    baNet = BaNetwork.load_json('my_networks/ws1.json')
    par = PonziParameters(M=1, starting_capital=50, lambda_ = lambda t: x, mu=lambda t:0.05, rp= lambda t: 0.1, rr=lambda t: 0.05)
    sim = PonziSimulation(baNet, par, max_time_units=30*12)
    res = sim.simulate_ponzi()
    plotter.add_simulation(res, r'$\lambda=' + str(x) + '$', show_potential=False)
plotter.plot('changing_lambda_ws')
# Out:
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete

# %%
erNet, baNet = ErNetwork.load_json('my_networks/er1.json'), BaNetwork.load_json('my_networks/ba1.json')
wsNet = WattsStrogatzNetwork.load_json('my_networks/ws1.json')
networks = [erNet, baNet, wsNet]
par = PonziParameters(M=1, starting_capital=50, lambda_ = lambda t: 0.01, mu=lambda t:0.1, rp= lambda t: 0.1, rr=lambda t: 0.05)

labels = ['ER', 'BA', 'WS']
i=0
plotter = PonziPlotter()
for (net, lab) in zip(networks, labels):
    sim = PonziSimulation(net, par, max_time_units=30*12)
    res = sim.simulate_ponzi()
    plotter.add_simulation(res, lab, show_potential=False)
plotter.plot('confronto_lambda_crit')
# Out:
# Network caricato da my_networks/er1.json
# Network caricato da my_networks/ba1.json
# Network caricato da my_networks/ws1.json
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete
# Starting simulation
# 5.00% complete
# 10.00% complete
# 15.28% complete
# 20.28% complete
# 25.28% complete
# 30.28% complete
# 35.28% complete
# 40.28% complete
# 45.28% complete
# 50.28% complete
# 55.28% complete
# 60.56% complete
# 65.56% complete
# 70.56% complete
# 75.83% complete
# 80.83% complete
# 86.11% complete
# 91.39% complete
# 96.39% complete

# %%
import numpy as np
for net in networks:
    mu = 0.1
    k_dist = net.k_distribution()
    print('k_crit ', mu * k_dist.mean() / np.mean(np.square(k_dist)))
# Out:
# k_crit  0.016630495566266345
# k_crit  0.006517926988265972
